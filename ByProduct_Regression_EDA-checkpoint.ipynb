# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('Data_NH3_LL_V5_final.csv')

print(dataset.shape)
# Out:
# (5002, 23)

# %%
dataset.columns.to_list()
# Out:
# ['DATE',
#  'TIME_SUBSHIFT',
#  'ORDER_SEQ',
#  'FREE_AMMN_PPM_LL',
#  'FREE_AMMN_PPM_EL',
#  'TOT_RICH_LIQ_TO_DACDFR',
#  'NH3_IN_RICH_LIQ',
#  'FREE_AMMN_PPM_SW',
#  'STRPDWTR4M_AMMS_TO_STRPDWTRTK',
#  'NH3_IN_STRP_WTR',
#  'FREE_AMMN_PPM_WW',
#  'WASTE_WTR_TO_BOD',
#  'NH3_IN_WW',
#  'TOP_PRESS_DEACIDIFIER',
#  'BOTTOM_PRESSURE_DEACIDIFIER',
#  'TOP_TEMP_DEACIDFIER',
#  'BOTTOM_TEMP_DEACIDIFIER',
#  'RICH_LIQ_TEMP_DEACIDIFIER',
#  'SOUR_GAS_TO_CLAUS_KILN',
#  'VAP_TE_NH4_STRP_TO_DEACID',
#  'TOT_FLOW_STEAM_TO_ASDF',
#  'STEAM_FLOW_FROM_SRU',
#  'STEAM_TO_STRIPPER']

# %%
dataset.head(50)
# Out:
#                    DATE TIME_SUBSHIFT  ORDER_SEQ  FREE_AMMN_PPM_LL  \
# 0   2019-02-05 00:00:00            C2          1             20060
# 1   2019-02-05 00:00:00            A1          2             25670
# 2   2019-02-05 00:00:00            A2          3             24310
# 3   2019-02-05 00:00:00            B1          4             21590
# 4   2019-02-05 00:00:00            B2          5             20400
# 5   2019-02-05 00:00:00            C1          6             19890
# 6   2019-02-06 00:00:00            C2          1             27200
# 7   2019-02-06 00:00:00            A1          2             20910
# 8   2019-02-06 00:00:00            A2          3             22100
# 9   2019-02-06 00:00:00            B1          4             23630
# 10  2019-02-06 00:00:00            B2          5             25840
# 11  2019-02-06 00:00:00            C1          6             24480
# 12  2019-02-07 00:00:00            C2          1             18020
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5002 entries, 0 to 5001
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATE                           5002 non-null   object
#  1   TIME_SUBSHIFT                  5002 non-null   object
#  2   ORDER_SEQ                      5002 non-null   int64
#  3   FREE_AMMN_PPM_LL               5002 non-null   int64
#  4   FREE_AMMN_PPM_EL               5002 non-null   int64
#  5   TOT_RICH_LIQ_TO_DACDFR         5002 non-null   float64
#  6   NH3_IN_RICH_LIQ                5002 non-null   float64
#  7   FREE_AMMN_PPM_SW               5002 non-null   int64
#  8   STRPDWTR4M_AMMS_TO_STRPDWTRTK  5002 non-null   float64
#  9   NH3_IN_STRP_WTR                5002 non-null   float64
#  10  FREE_AMMN_PPM_WW               5002 non-null   int64
#  11  WASTE_WTR_TO_BOD               5002 non-null   float64
# ...

# %%
dataset.describe()
# Out:
#          ORDER_SEQ  FREE_AMMN_PPM_LL  FREE_AMMN_PPM_EL  \
# count  5002.000000       5002.000000       5002.000000
# mean      3.499800      19662.841863      13523.131547
# std       1.709946       3038.581519       2287.659453
# min       1.000000      11730.000000       8160.000000
# 25%       2.000000      17510.000000      11900.000000
# 50%       3.000000      19380.000000      13260.000000
# 75%       5.000000      21420.000000      14960.000000
# max       6.000000      28220.000000      22100.000000
#
#        TOT_RICH_LIQ_TO_DACDFR  NH3_IN_RICH_LIQ  FREE_AMMN_PPM_SW  \
# count             5002.000000     5.002000e+03       5002.000000
# mean               145.370286     1.975176e+06        377.133147
# std                 19.518492     4.741735e+05        283.173626
# min                110.154727     9.801700e+05         51.000000
# 25%                128.188739     1.609806e+06        238.000000
# 50%                144.761129     1.901636e+06        306.000000
# ...

# %%
dataset.describe(percentiles=[0.01,0.1,0.15,0.25,0.75,0.90])
# Out:
#          ORDER_SEQ  FREE_AMMN_PPM_LL  FREE_AMMN_PPM_EL  \
# count  5002.000000       5002.000000       5002.000000
# mean      3.499800      19662.841863      13523.131547
# std       1.709946       3038.581519       2287.659453
# min       1.000000      11730.000000       8160.000000
# 1%        1.000000      13600.000000       9180.000000
# 10%       1.000000      15980.000000      10710.000000
# 15%       1.000000      16660.000000      11220.000000
# 25%       2.000000      17510.000000      11900.000000
# 50%       3.000000      19380.000000      13260.000000
# 75%       5.000000      21420.000000      14960.000000
# 90%       6.000000      23800.000000      16660.000000
# max       6.000000      28220.000000      22100.000000
#
#        TOT_RICH_LIQ_TO_DACDFR  NH3_IN_RICH_LIQ  FREE_AMMN_PPM_SW  \
# count             5002.000000     5.002000e+03       5002.000000
# mean               145.370286     1.975176e+06        377.133147
# ...

# %%
dataset.isnull().sum()
# Out:
# DATE                             0
# TIME_SUBSHIFT                    0
# ORDER_SEQ                        0
# FREE_AMMN_PPM_LL                 0
# FREE_AMMN_PPM_EL                 0
# TOT_RICH_LIQ_TO_DACDFR           0
# NH3_IN_RICH_LIQ                  0
# FREE_AMMN_PPM_SW                 0
# STRPDWTR4M_AMMS_TO_STRPDWTRTK    0
# NH3_IN_STRP_WTR                  0
# FREE_AMMN_PPM_WW                 0
# WASTE_WTR_TO_BOD                 0
# NH3_IN_WW                        0
# TOP_PRESS_DEACIDIFIER            0
# BOTTOM_PRESSURE_DEACIDIFIER      0
# TOP_TEMP_DEACIDFIER              0
# BOTTOM_TEMP_DEACIDIFIER          0
# RICH_LIQ_TEMP_DEACIDIFIER        0
# SOUR_GAS_TO_CLAUS_KILN           0
# VAP_TE_NH4_STRP_TO_DEACID        0
# TOT_FLOW_STEAM_TO_ASDF           0
# STEAM_FLOW_FROM_SRU              0
# STEAM_TO_STRIPPER                0
# dtype: int64

# %% [markdown]
# ## Categorical Features

# %%
categ_features=[feature for feature in dataset.columns if dataset[feature].dtypes=='O']
categ_features
# Out:
# ['DATE', 'TIME_SUBSHIFT']

# %%
dataset[categ_features].head(15)
# Out:
#                    DATE TIME_SUBSHIFT
# 0   2019-02-05 00:00:00            C2
# 1   2019-02-05 00:00:00            A1
# 2   2019-02-05 00:00:00            A2
# 3   2019-02-05 00:00:00            B1
# 4   2019-02-05 00:00:00            B2
# 5   2019-02-05 00:00:00            C1
# 6   2019-02-06 00:00:00            C2
# 7   2019-02-06 00:00:00            A1
# 8   2019-02-06 00:00:00            A2
# 9   2019-02-06 00:00:00            B1
# 10  2019-02-06 00:00:00            B2
# 11  2019-02-06 00:00:00            C1
# 12  2019-02-07 00:00:00            C2
# 13  2019-02-07 00:00:00            A1
# 14  2019-02-07 00:00:00            A2

# %%
dataset["DATE"]=pd.to_datetime(dataset["DATE"])

# %%
dataset.head()
dataset.set_index("DATE").head()
# Out:
#            TIME_SUBSHIFT  ORDER_SEQ  FREE_AMMN_PPM_LL  FREE_AMMN_PPM_EL  \
# DATE
# 2019-02-05            C2          1             20060             14280
# 2019-02-05            A1          2             25670             16150
# 2019-02-05            A2          3             24310             15810
# 2019-02-05            B1          4             21590             14450
# 2019-02-05            B2          5             20400             14280
#
#             TOT_RICH_LIQ_TO_DACDFR  NH3_IN_RICH_LIQ  FREE_AMMN_PPM_SW  \
# DATE
# 2019-02-05              162.504666      2320566.626               544
# 2019-02-05              161.827740      2613518.001               765
# 2019-02-05              162.268929      2565471.761               816
# 2019-02-05              170.922289      2469827.070               680
# 2019-02-05              171.131043      2443751.292               510
#
#             STRPDWTR4M_AMMS_TO_STRPDWTRTK  NH3_IN_STRP_WTR  FREE_AMMN_PPM_WW  \
# DATE
# ...

# %%
dataset["DATE"].max()-dataset["DATE"].min()
# Out:
# Timedelta('999 days 00:00:00')

# %% [markdown]
# ## Numerical Features

# %%
num_features=[features for features in dataset.columns if dataset[features].dtype !='O']
print('Number of numerical variables: ',len(num_features))
# Out:
# Number of numerical variables:  22

# %%
dataset.hist(bins=60 , figsize=(22,13))
# Out:
# array([[<Axes: title={'center': 'DATE'}>,
#         <Axes: title={'center': 'ORDER_SEQ'}>,
#         <Axes: title={'center': 'FREE_AMMN_PPM_LL'}>,
#         <Axes: title={'center': 'FREE_AMMN_PPM_EL'}>,
#         <Axes: title={'center': 'TOT_RICH_LIQ_TO_DACDFR'}>],
#        [<Axes: title={'center': 'NH3_IN_RICH_LIQ'}>,
#         <Axes: title={'center': 'FREE_AMMN_PPM_SW'}>,
#         <Axes: title={'center': 'STRPDWTR4M_AMMS_TO_STRPDWTRTK'}>,
#         <Axes: title={'center': 'NH3_IN_STRP_WTR'}>,
#         <Axes: title={'center': 'FREE_AMMN_PPM_WW'}>],
#        [<Axes: title={'center': 'WASTE_WTR_TO_BOD'}>,
#         <Axes: title={'center': 'NH3_IN_WW'}>,
#         <Axes: title={'center': 'TOP_PRESS_DEACIDIFIER'}>,
#         <Axes: title={'center': 'BOTTOM_PRESSURE_DEACIDIFIER'}>,
#         <Axes: title={'center': 'TOP_TEMP_DEACIDFIER'}>],
#        [<Axes: title={'center': 'BOTTOM_TEMP_DEACIDIFIER'}>,
#         <Axes: title={'center': 'RICH_LIQ_TEMP_DEACIDIFIER'}>,
# ...

# %%
ammnllprod=dataset[dataset['FREE_AMMN_PPM_LL']>25000]
ammnllprod
# Out:
#            DATE TIME_SUBSHIFT  ORDER_SEQ  FREE_AMMN_PPM_LL  FREE_AMMN_PPM_EL  \
# 1    2019-02-05            A1          2             25670             16150
# 6    2019-02-06            C2          1             27200             17170
# 10   2019-02-06            B2          5             25840             17000
# 55   2019-02-15            A1          2             27200             17680
# 56   2019-02-15            A2          3             28050             16660
# ...         ...           ...        ...               ...               ...
# 3092 2020-10-28            B1          4             25500             18700
# 3288 2020-12-07            A1          2             26860             19720
# 3810 2021-03-12            B2          5             25500             14790
# 3947 2021-04-05            C2          1             26690             12750
# 4969 2021-10-26            B1          4             25160             12580
#
# ...

# %%
ammnllprod[['FREE_AMMN_PPM_LL','NH3_IN_RICH_LIQ']].plot(kind='scatter',x='FREE_AMMN_PPM_LL',y='NH3_IN_RICH_LIQ',figsize=(11,7))
# Out:
# <Axes: xlabel='FREE_AMMN_PPM_LL', ylabel='NH3_IN_RICH_LIQ'>

# %%
ammnelprod=dataset[dataset['FREE_AMMN_PPM_EL']>18000]
ammnelprod
# Out:
#            DATE TIME_SUBSHIFT  ORDER_SEQ  FREE_AMMN_PPM_LL  FREE_AMMN_PPM_EL  \
# 73   2019-02-18            A2          3             27200             20910
# 86   2019-02-21            C2          1             27880             19380
# 91   2019-02-21            C1          6             27540             18700
# 92   2019-02-22            C2          1             23970             18190
# 95   2019-02-22            B2          5             24480             19040
# ...         ...           ...        ...               ...               ...
# 4527 2021-08-01            C1          6             19040             18360
# 4529 2021-08-02            A1          2             19210             18190
# 4543 2021-08-04            B2          5             21080             19550
# 4573 2021-08-09            B2          5             17850             18020
# 4587 2021-08-12            A1          2             20060             18020
#
# ...

# %%
ammnelprod[['FREE_AMMN_PPM_EL','NH3_IN_RICH_LIQ']].plot(kind='scatter',x='FREE_AMMN_PPM_EL',y='NH3_IN_RICH_LIQ',figsize=(10,7))
# Out:
# <Axes: xlabel='FREE_AMMN_PPM_EL', ylabel='NH3_IN_RICH_LIQ'>

# %%
nh3richliq=dataset[dataset['NH3_IN_RICH_LIQ']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 nh3richliq=dataset[dataset['NH3_IN_RICH_LIQ']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# ...
